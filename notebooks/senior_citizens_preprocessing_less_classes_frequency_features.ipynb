# %% [markdown]
# ## Preprocess of the Senior Citizens dataset
#
# - Loading the initial dataset(s)
# - Renaming the columns
# - Removing labels or concatenating them
# - Making the labels from strings to integers
# - Cleaning the data
# - Lowpass filter
# - Downsampling the signals
# - Calculating the acceleration magnitude as feature
# - Splitting the data into windows and features
# - Saving the datasets per users and concatenated

# %%
# Importing libraries needed
import os
import sys

import numpy as np
import pandas as pd

sys.path.append(os.path.abspath(os.path.join('../src/utils/')))
import downsampling
import feature_extraction
import preprocessing

# %%
# Read the raw data
user_id_dataframes = []
dataset_path = r'../data/activity_recognition_senior_citizens/'
for user_id in os.listdir(dataset_path):
    if user_id.endswith('.csv'):
        user_id_dataframes.append(pd.read_csv(dataset_path + user_id))

# %%
# Checking the basic info of the data
for user_id_dataframe in user_id_dataframes:
    print(user_id_dataframe.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103860 entries, 0 to 103859
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  103860 non-null  object
#  1   back_x     103860 non-null  float64
#  2   back_y     103860 non-null  float64
#  3   back_z     103860 non-null  float64
#  4   thigh_x    103860 non-null  float64
#  5   thigh_y    103860 non-null  float64
#  6   thigh_z    103860 non-null  float64
#  7   label      103860 non-null  int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 6.3+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131367 entries, 0 to 131366
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  131367 non-null  object
#  1   back_x     131367 non-null  float64
#  2   back_y     131367 non-null  float64
#  3   back_z     131367 non-null  float64
#  4   thigh_x    131367 non-null  float64
#  5   thigh_y    131367 non-null  float64
#  6   thigh_z    131367 non-null  float64
#  7   label      131367 non-null  int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 8.0+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116413 entries, 0 to 116412
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  116413 non-null  object
#  1   back_x     116413 non-null  float64
#  2   back_y     116413 non-null  float64
#  3   back_z     116413 non-null  float64
#  4   thigh_x    116413 non-null  float64
#  5   thigh_y    116413 non-null  float64
#  6   thigh_z    116413 non-null  float64
#  7   label      116413 non-null  int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 7.1+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150758 entries, 0 to 150757
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  150758 non-null  object
#  1   back_x     150758 non-null  float64
#  2   back_y     150758 non-null  float64
#  3   back_z     150758 non-null  float64
#  4   thigh_x    150758 non-null  float64
#  5   thigh_y    150758 non-null  float64
#  6   thigh_z    150758 non-null  float64
#  7   label      150758 non-null  int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 9.2+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87006 entries, 0 to 87005
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  87006 non-null  object
#  1   back_x     87006 non-null  float64
#  2   back_y     87006 non-null  float64
#  3   back_z     87006 non-null  float64
#  4   thigh_x    87006 non-null  float64
#  5   thigh_y    87006 non-null  float64
#  6   thigh_z    87006 non-null  float64
#  7   label      87006 non-null  int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 5.3+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122714 entries, 0 to 122713
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  122714 non-null  object
#  1   back_x     122714 non-null  float64
#  2   back_y     122714 non-null  float64
#  3   back_z     122714 non-null  float64
#  4   thigh_x    122714 non-null  float64
#  5   thigh_y    122714 non-null  float64
#  6   thigh_z    122714 non-null  float64
#  7   label      122714 non-null  int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 7.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120125 entries, 0 to 120124
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  120125 non-null  object
#  1   back_x     120125 non-null  float64
#  2   back_y     120125 non-null  float64
#  3   back_z     120125 non-null  float64
#  4   thigh_x    120125 non-null  float64
#  5   thigh_y    120125 non-null  float64
#  6   thigh_z    120125 non-null  float64
#  7   label      120125 non-null  int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 7.3+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130494 entries, 0 to 130493
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  130494 non-null  object
#  1   back_x     130494 non-null  float64
#  2   back_y     130494 non-null  float64
#  3   back_z     130494 non-null  float64
#  4   thigh_x    130494 non-null  float64
#  5   thigh_y    130494 non-null  float64
#  6   thigh_z    130494 non-null  float64
#  7   label      130494 non-null  int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 8.0+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121763 entries, 0 to 121762
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  121763 non-null  object
#  1   back_x     121763 non-null  float64
#  2   back_y     121763 non-null  float64
#  3   back_z     121763 non-null  float64
#  4   thigh_x    121763 non-null  float64
#  5   thigh_y    121763 non-null  float64
#  6   thigh_z    121763 non-null  float64
#  7   label      121763 non-null  int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 7.4+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122061 entries, 0 to 122060
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  122061 non-null  object
#  1   back_x     122061 non-null  float64
#  2   back_y     122061 non-null  float64
#  3   back_z     122061 non-null  float64
#  4   thigh_x    122061 non-null  float64
#  5   thigh_y    122061 non-null  float64
#  6   thigh_z    122061 non-null  float64
#  7   label      122061 non-null  int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 7.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128063 entries, 0 to 128062
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  128063 non-null  object
#  1   back_x     128063 non-null  float64
#  2   back_y     128063 non-null  float64
#  3   back_z     128063 non-null  float64
#  4   thigh_x    128063 non-null  float64
#  5   thigh_y    128063 non-null  float64
#  6   thigh_z    128063 non-null  float64
#  7   label      128063 non-null  int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 7.8+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119310 entries, 0 to 119309
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  119310 non-null  object
#  1   back_x     119310 non-null  float64
#  2   back_y     119310 non-null  float64
#  3   back_z     119310 non-null  float64
#  4   thigh_x    119310 non-null  float64
#  5   thigh_y    119310 non-null  float64
#  6   thigh_z    119310 non-null  float64
#  7   label      119310 non-null  int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 7.3+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123599 entries, 0 to 123598
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  123599 non-null  object
#  1   back_x     123599 non-null  float64
#  2   back_y     123599 non-null  float64
#  3   back_z     123599 non-null  float64
#  4   thigh_x    123599 non-null  float64
#  5   thigh_y    123599 non-null  float64
#  6   thigh_z    123599 non-null  float64
#  7   label      123599 non-null  int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 7.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101510 entries, 0 to 101509
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  101510 non-null  object
#  1   back_x     101510 non-null  float64
#  2   back_y     101510 non-null  float64
#  3   back_z     101510 non-null  float64
#  4   thigh_x    101510 non-null  float64
#  5   thigh_y    101510 non-null  float64
#  6   thigh_z    101510 non-null  float64
#  7   label      101510 non-null  int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 6.2+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153517 entries, 0 to 153516
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  153517 non-null  object
#  1   back_x     153517 non-null  float64
#  2   back_y     153517 non-null  float64
#  3   back_z     153517 non-null  float64
#  4   thigh_x    153517 non-null  float64
#  5   thigh_y    153517 non-null  float64
#  6   thigh_z    153517 non-null  float64
#  7   label      153517 non-null  int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 9.4+ MB
# None

# %%
# Rename the columns
for user_id_dataframe in user_id_dataframes:
    user_id_dataframe.columns = ['Timestamp', 'Acc.X.Back', 'Acc.Y.Back', 'Acc.Z.Back', 'Acc.X.Thigh', 'Acc.Y.Thigh', 'Acc.Z.Thigh', 'Label']

# %%
# Checking the changes
user_id_dataframes[0].head()
# Out:
#                  Timestamp  Acc.X.Back  Acc.Y.Back  Acc.Z.Back  Acc.X.Thigh  \
# 0  2021-03-24 14:42:03.839   -0.999023   -0.063477    0.140625    -0.980469
# 1  2021-03-24 14:42:03.859   -0.980225   -0.079346    0.140625    -0.961182
# 2  2021-03-24 14:42:03.880   -0.950195   -0.076416    0.140625    -0.949463
# 3  2021-03-24 14:42:03.900   -0.954834   -0.059082    0.140381    -0.957520
# 4  2021-03-24 14:42:03.920   -0.972412   -0.042969    0.142822    -0.977051
#
#    Acc.Y.Thigh  Acc.Z.Thigh  Label
# 0    -0.112061    -0.048096      6
# 1    -0.121582    -0.051758      6
# 2    -0.080566    -0.067139      6
# 3    -0.046143    -0.050781      6
# 4    -0.023682    -0.026611      6

# %%
# Checking the unique values of the labels
# 1. walking, 3.shuffling, 4. stairs (ascending), 5. stairs (descending), 6. standing, 7. sitting, 8. lying
labels = []
for user_id_dataframe in user_id_dataframes:
    labels.extend(user_id_dataframe['Label'].unique())
labels = list(set(labels))
print(labels)
# Out:
# [1, 3, 4, 5, 6, 7, 8]

# %%
# The labels 4,5(stairs (ascending), stairs (descending)) make them 4, 6,7,8(standing, sitting, lying) make them 5
for user_id_dataframe in user_id_dataframes:
    user_id_dataframe['Label'] = user_id_dataframe['Label'].replace([5], 4)
    user_id_dataframe['Label'] = user_id_dataframe['Label'].replace([6, 7, 8], 5)

# %%
# Checking the unique values of the labels
labels = []
for user_id_dataframe in user_id_dataframes:
    labels.extend(user_id_dataframe['Label'].unique())
labels = list(set(labels))
print(labels)
# Out:
# [1, 3, 4, 5]

# %%
# Map the labels to numbers
map_dict = {1:1, 3:2, 4:3, 5:4}
for user_id_dataframe in user_id_dataframes:
    user_id_dataframe['Label'] = user_id_dataframe['Label'].map(map_dict)

# %%
# Checking the unique values of the labels
labels = []
for user_id_dataframe in user_id_dataframes:
    labels.extend(user_id_dataframe['Label'].unique())
labels = list(set(labels))
print(labels)
# Out:
# [1, 2, 3, 4]

# %%
# Checking the changes
user_id_dataframes[0].head()
# Out:
#                  Timestamp  Acc.X.Back  Acc.Y.Back  Acc.Z.Back  Acc.X.Thigh  \
# 0  2021-03-24 14:42:03.839   -0.999023   -0.063477    0.140625    -0.980469
# 1  2021-03-24 14:42:03.859   -0.980225   -0.079346    0.140625    -0.961182
# 2  2021-03-24 14:42:03.880   -0.950195   -0.076416    0.140625    -0.949463
# 3  2021-03-24 14:42:03.900   -0.954834   -0.059082    0.140381    -0.957520
# 4  2021-03-24 14:42:03.920   -0.972412   -0.042969    0.142822    -0.977051
#
#    Acc.Y.Thigh  Acc.Z.Thigh  Label
# 0    -0.112061    -0.048096      4
# 1    -0.121582    -0.051758      4
# 2    -0.080566    -0.067139      4
# 3    -0.046143    -0.050781      4
# 4    -0.023682    -0.026611      4

# %%
# Setting the parameters for the preprocessing
old_sampling_frequency = 100
new_sampling_frequency = 20
cutoff_frequency = 5
order = 3

# %%
# Lowpass filter the sensor data, downsample the data and calculate the magnitude of the acceleration
col_signals_back = ['Acc.X.Back', 'Acc.Y.Back', 'Acc.Z.Back']
col_signals_thigh = ['Acc.X.Thigh', 'Acc.Y.Thigh', 'Acc.Z.Thigh']
for user_id_dataframe in user_id_dataframes:
    for col in col_signals_back + col_signals_thigh:
        user_id_dataframe[col] = preprocessing.lowpass_filter(user_id_dataframe[col], old_sampling_frequency, cutoff_frequency, order)
        user_id_dataframe[col] = downsampling.downsample_signal(user_id_dataframe[col], old_sampling_frequency, new_sampling_frequency, None)
    user_id_dataframe = preprocessing.calculate_mag(user_id_dataframe, col_signals_back)
    user_id_dataframe = preprocessing.calculate_mag(user_id_dataframe, col_signals_thigh)
    labels = user_id_dataframe['Label']
    user_id_dataframe.drop('Label', axis=1, inplace=True)
    user_id_dataframe['Label'] = labels

# %%
# Checking the changes
user_id_dataframes[0].head()
# Out:
#                  Timestamp  Acc.X.Back  Acc.Y.Back  Acc.Z.Back  Acc.X.Thigh  \
# 0  2021-03-24 14:42:03.839   -0.998972   -0.063252    0.140358    -0.980321
# 1  2021-03-24 14:42:03.859   -0.998972   -0.063252    0.140358    -0.980321
# 2  2021-03-24 14:42:03.880   -0.998972   -0.063252    0.140358    -0.980321
# 3  2021-03-24 14:42:03.900   -0.998972   -0.063252    0.140358    -0.980321
# 4  2021-03-24 14:42:03.920   -0.998972   -0.063252    0.140358    -0.980321
#
#    Acc.Y.Thigh  Acc.Z.Thigh  Acc.Magnitude.Back  Acc.Magnitude.Thigh  Label
# 0    -0.113319    -0.047163            1.010765             0.987976      4
# 1    -0.113319    -0.047163            1.010765             0.987976      4
# 2    -0.113319    -0.047163            1.010765             0.987976      4
# 3    -0.113319    -0.047163            1.010765             0.987976      4
# 4    -0.113319    -0.047163            1.010765             0.987976      4

# %%
# Setting the parameters for the feature extraction
window_duration = 0.3
overlap = 0.3
win_length = int(window_duration * new_sampling_frequency)
overlap = int(overlap * new_sampling_frequency)
col_extract = col_signals_back + col_signals_thigh + ['Acc.Magnitude.Back', 'Acc.Magnitude.Thigh']

# %%
# Extracting the features and generating the labels for each user
new_user_id_dataframes = []
for user_id_dataframe in user_id_dataframes:
    features = feature_extraction.calculate_features(user_id_dataframe, col_extract, win_length, overlap)
    labels = feature_extraction.generate_labels(user_id_dataframe, 'Label', win_length, overlap)
    features['Label'] = labels
    new_user_id_dataframes.append(features)
# Out:
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:56: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   labels = np.apply_along_axis(lambda x: stats.mode(x).mode, 1, labels)
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:56: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   labels = np.apply_along_axis(lambda x: stats.mode(x).mode, 1, labels)
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:56: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   labels = np.apply_along_axis(lambda x: stats.mode(x).mode, 1, labels)
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:56: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   labels = np.apply_along_axis(lambda x: stats.mode(x).mode, 1, labels)
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:56: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   labels = np.apply_along_axis(lambda x: stats.mode(x).mode, 1, labels)
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:56: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   labels = np.apply_along_axis(lambda x: stats.mode(x).mode, 1, labels)
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:56: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   labels = np.apply_along_axis(lambda x: stats.mode(x).mode, 1, labels)
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:56: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   labels = np.apply_along_axis(lambda x: stats.mode(x).mode, 1, labels)
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:56: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   labels = np.apply_along_axis(lambda x: stats.mode(x).mode, 1, labels)
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:56: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   labels = np.apply_along_axis(lambda x: stats.mode(x).mode, 1, labels)
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:56: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   labels = np.apply_along_axis(lambda x: stats.mode(x).mode, 1, labels)
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:56: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   labels = np.apply_along_axis(lambda x: stats.mode(x).mode, 1, labels)
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:56: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   labels = np.apply_along_axis(lambda x: stats.mode(x).mode, 1, labels)
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:56: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   labels = np.apply_along_axis(lambda x: stats.mode(x).mode, 1, labels)
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:84: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis = stats.kurtosis(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:85: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data, axis=1).reshape((-1, 1))
# d:\Work\HAR-Comparison-Privacy\src\utils\feature_extraction.py:56: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   labels = np.apply_along_axis(lambda x: stats.mode(x).mode, 1, labels)

# %%
# Saving the data
processed_path = r"../processed_data/activity_recognition_senior_citizens_less_classes_frequency_features/"
all_users_data = pd.DataFrame()
if not os.path.exists(processed_path):
    os.makedirs(processed_path)
for i in range(len(new_user_id_dataframes)):
    new_user_id_dataframes[i].insert(0, 'User_ID', i+1)
    new_user_id_dataframes[i].to_csv(processed_path + 'user_' + str(i+1) + '.csv', index=False)
    all_users_data = pd.concat([all_users_data, new_user_id_dataframes[i]])
all_users_data.to_csv(processed_path + 'all_users.csv', index=False)
